# %%
from dataset_gbm import HistoricalMarketDatasetMultivar

# %%
kwargs = {
    'n_paths': 10000,
    'n_steps': 256,
    'n_ts_features': 1,
    'return_log_returns': True,
    'normalize': 'global_zscore',
    'noise_type': 've',
    'sigma': 0.03,
    'corruption_probability': 0.5,   
}

dataset = HistoricalMarketDatasetMultivar(**kwargs)
# Out:
# ...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  5 of 5 completed
#
# 5 Failed downloads:
# ['AACG', 'AACB', 'AACT', 'A', 'AA']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ...
# [**********************80%*************          ]  4 of 5 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 12
#       1 kwargs = {
#       2     'n_paths': 10000,
#       3     'n_steps': 256,
#    (...)
#       9     'corruption_probability': 0.5,
#      10 }
# ---> 12 dataset = HistoricalMarketDatasetMultivar(**kwargs)
#
# File ~/ambient-laws/dataset_gbm.py:751, in HistoricalMarketDatasetMultivar.__init__(self, start, end, symbols, **kwargs)
#     749 self.start = start
#     750 self.end = end
# --> 751 self.paths = self.load_data()
#     752 self.process_paths()
# ...

# %%
dataset.paths.shape
# Out:
# (2, 4, 252)
